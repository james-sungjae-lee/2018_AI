# %% [markdown]
# ## Artificial Intelligence Assignment 2
# ## No4. Neural Network 2
# ## 20132651 Sungjae Lee

# %%
import torch

# %%
N, D_in, H, D_out = 64, 1000, 100, 10

# 앞에서와 동일하게 N, D_in, H, D_out 값을 설정합니다

# %%
x = torch.randn(N, D_in)
y = torch.randn(N, D_out)
w1 = torch.randn(D_in, H, requires_grad=True)
w2 = torch.randn(H, D_out, requires_grad=True)

# 앞에서와 동일하게 x, y, w1, w2 값을 설정합니다

# %%
learning_rate = 10e-6
loss_list = []

# 이번에도 마찬가지로 learning rate 를 10e - 06 으로 주며,
# loss 의 변화를 알아보기 위해 loss_list 를 생성합니다

# %%
for t in range(500):
    y_pred = x.mm(w1).clamp(min=0).mm(w2)
    loss = (y_pred - y).pow(2).sum()
    loss_list.append(loss.item())
    print(t, loss.item())

    loss.backward()

    with torch.no_grad():
        w1 -= learning_rate * w1.grad
        w2 -= learning_rate * w2.grad

        w1.grad.zero_()
        w2.grad.zero_()
        
# 아까와 다르게 이번에는 loss 에 backward 메소드를 사용하여 간단하게 backprop 을 진행합니다
# w1 과 w2 의 grad 를 이용하여 가중치값을 갱신해주면 됩니다
# no_grad 는 requires_grad 를 일시적으로 False 로 만들어주는 것입니다.
# Out:
# 0 24651320.0
# 1 1628035840.0
# 2 1122984787968.0
# 3 3.9990318062436247e+21
# 4 inf
# 5 inf
# 6 nan
# 7 nan
# 8 nan
# 9 nan
# 10 nan
# 11 nan
# 12 nan
# 13 nan
# 14 nan
# 15 nan
# 16 nan
# 17 nan
# 18 nan
# 19 nan
# 20 nan
# 21 nan
# 22 nan
# 23 nan
# 24 nan
# 25 nan
# 26 nan
# 27 nan
# 28 nan
# 29 nan
# 30 nan
# 31 nan
# 32 nan
# 33 nan
# 34 nan
# 35 nan
# 36 nan
# 37 nan
# 38 nan
# 39 nan
# 40 nan
# 41 nan
# 42 nan
# 43 nan
# 44 nan
# 45 nan
# 46 nan
# 47 nan
# 48 nan
# 49 nan
# 50 nan
# 51 nan
# 52 nan
# 53 nan
# 54 nan
# 55 nan
# 56 nan
# 57 nan
# 58 nan
# 59 nan
# 60 nan
# 61 nan
# 62 nan
# 63 nan
# 64 nan
# 65 nan
# 66 nan
# 67 nan
# 68 nan
# 69 nan
# 70 nan
# 71 nan
# 72 nan
# 73 nan
# 74 nan
# 75 nan
# 76 nan
# 77 nan
# 78 nan
# 79 nan
# 80 nan
# 81 nan
# 82 nan
# 83 nan
# 84 nan
# 85 nan
# 86 nan
# 87 nan
# 88 nan
# 89 nan
# 90 nan
# 91 nan
# 92 nan
# 93 nan
# 94 nan
# 95 nan
# 96 nan
# 97 nan
# 98 nan
# 99 nan
# 100 nan
# 101 nan
# 102 nan
# 103 nan
# 104 nan
# 105 nan
# ...

# %% [markdown]
# ### (1) y_pred에 따른 loss (accuracy) 변화를 화면 출력 확인 (plot)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(loss_list)
plt.show()

# %% [markdown]
# ### (2) 앞 문제의 코드와 비교

# %%
# 앞 문제의 코드와 비교하였을 때, 여전히 loss 가 발산하는 모습을 볼 수 있습니다.
# 여전히 learning rate 의 수정이 이루어지지 않고, 계산 코드만 간결하게 줄인 것이기 때문입니다.
# 이를 해결하기 위해서는 learning_rate 값을 더 작게 수정하는 것이 필요합니다
